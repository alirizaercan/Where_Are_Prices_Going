# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from collections import Counter
from matplotlib.ticker import MaxNLocator

# %%
df = pd.read_csv('son_hali.csv')
df.head()
# Out:
#      _id       tarih  urun_ad birim  tur  en_dusuk_fiyat  en_yuksek_fiyat  \
# 0  27289  2010-12-01  AVAKADO  Adet    1             1.2              1.6
# 1  27289  2010-12-01  AVAKADO  Adet    1             1.2              1.6
# 2  27289  2010-12-01  AVAKADO  Adet    1             1.2              1.6
# 3  27289  2010-12-01  AVAKADO  Adet    1             1.2              1.6
# 4  27289  2010-12-01  AVAKADO  Adet    1             1.2              1.6
#
#    ortalama_fiyat  benzin  asgari_ucret
# 0             1.4    3.86        599.12
# 1             1.4    3.86        599.12
# 2             1.4    3.84        599.12
# 3             1.4    3.84        599.12
# 4             1.4    3.84        599.12

# %%
sebzeler = df[df['tur'] == 0]
meyveler = df[df['tur'] == 1]

# Her bir kategorideki tekrar eden değerleri hesaplayıp yazdırıyoruz
print("Sebzelerdeki Tekrar Eden Değerler:")
print(sebzeler['urun_ad'].value_counts())

print("\nMeyvelerdeki Tekrar Eden Değerler:")
print(meyveler['urun_ad'].value_counts())
# Out:
# Sebzelerdeki Tekrar Eden Değerler:
# urun_ad
# PATATES                   10995
# PATLICAN (Kemer)          10888
# PATLICAN (Topak)          10876
# BİBER (Dolma)             10868
# MANTAR (Kültür)           10864
# BİBER (Kıl)               10856
# MARUL (Aysberk)Adet       10853
# BİBER (Çarli)             10853
# FASULYE (Muhtelif)        10851
# DOMATES (Muhtelif)        10831
# ISPANAK                   10825
# SEMİZ OTU(Bağ)            10823
# TERE                      10823
# SALATALIK (Silor)         10807
# SALATALIK (Muhtelif)      10797
# BİBER (Sivri)             10794
# DERE OTU (Bağ)            10794
# NANE(Bağ)                 10786
# ROKA(Bağ)                 10785
# FESLEĞEN(REYHAN)Bağ       10759
# SARIMSAK (Kuru)           10744
# EKŞİ OT (Bağ)             10727
# MAYDONOZ (Bağ)            10716
# LAHANA (Mor)              10714
# DOMATES (Çeri)            10675
# LAHANA (Beyaz)            10674
# KABAK (Beyaz)             10672
# DOMATES (Salkım)          10664
# ...
